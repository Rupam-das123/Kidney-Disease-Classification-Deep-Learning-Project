# %%
import os

# %%
# %pwd
# Out:
# 'd:\\major(kidney)\\Kidney-Disease-Classification-Deep-Learning-Project\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'd:\\major(kidney)\\Kidney-Disease-Classification-Deep-Learning-Project'

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir: Path
    source_URL: str
    local_data_file: Path
    unzip_dir: Path

# %%
# !pip install matplotlib seaborn python-box==6.0.2 pyYAML tqdm ensure==1.0.2 joblib types-PyYAML scipy Flask Flask-Cors gdown
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.7.5-cp38-cp38-win_amd64.whl.metadata (5.8 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: python-box==6.0.2 in d:\anaconda\envs\kidney\lib\site-packages (6.0.2)
# Requirement already satisfied: pyYAML in d:\anaconda\envs\kidney\lib\site-packages (6.0.3)
# Requirement already satisfied: tqdm in d:\anaconda\envs\kidney\lib\site-packages (4.67.3)
# Collecting ensure==1.0.2
#   Using cached ensure-1.0.2-py2.py3-none-any.whl.metadata (10 kB)
# Collecting joblib
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting types-PyYAML
#   Using cached types_PyYAML-6.0.12.20241230-py3-none-any.whl.metadata (1.8 kB)
# Collecting scipy
#   Using cached scipy-1.10.1-cp38-cp38-win_amd64.whl.metadata (58 kB)
# Collecting Flask
#   Using cached flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting Flask-Cors
#   Using cached Flask_Cors-5.0.0-py2.py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: gdown in d:\anaconda\envs\kidney\lib\site-packages (5.2.2)
# Requirement already satisfied: six>=1.11.0 in d:\anaconda\envs\kidney\lib\site-packages (from ensure==1.0.2) (1.16.0)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.1.1-cp38-cp38-win_amd64.whl.metadata (5.9 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.57.0-cp38-cp38-win_amd64.whl.metadata (104 kB)
# Collecting kiwisolver>=1.0.1 (from matplotlib)
#   Using cached kiwisolver-1.4.7-cp38-cp38-win_amd64.whl.metadata (6.4 kB)
# Collecting numpy<2,>=1.20 (from matplotlib)
#   Using cached numpy-1.24.4-cp38-cp38-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\envs\kidney\lib\site-packages (from matplotlib) (26.0)
# Collecting pillow>=6.2.0 (from matplotlib)
#   Using cached pillow-10.4.0-cp38-cp38-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\envs\kidney\lib\site-packages (from matplotlib) (2.9.0)
# Collecting importlib-resources>=3.2.0 (from matplotlib)
#   Using cached importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# Collecting pandas>=1.2 (from seaborn)
#   Using cached pandas-2.0.3-cp38-cp38-win_amd64.whl.metadata (18 kB)
# Requirement already satisfied: colorama in d:\anaconda\envs\kidney\lib\site-packages (from tqdm) (0.4.6)
# Collecting Werkzeug>=3.0.0 (from Flask)
#   Using cached werkzeug-3.0.6-py3-none-any.whl.metadata (3.7 kB)
# Collecting Jinja2>=3.1.2 (from Flask)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting itsdangerous>=2.1.2 (from Flask)
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting click>=8.1.3 (from Flask)
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting blinker>=1.6.2 (from Flask)
#   Using cached blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: importlib-metadata>=3.6.0 in d:\anaconda\envs\kidney\lib\site-packages (from Flask) (8.5.0)
# Requirement already satisfied: beautifulsoup4 in d:\anaconda\envs\kidney\lib\site-packages (from gdown) (4.14.3)
# Requirement already satisfied: filelock in d:\anaconda\envs\kidney\lib\site-packages (from gdown) (3.16.1)
# Requirement already satisfied: requests[socks] in d:\anaconda\envs\kidney\lib\site-packages (from gdown) (2.32.4)
# Requirement already satisfied: zipp>=3.20 in d:\anaconda\envs\kidney\lib\site-packages (from importlib-metadata>=3.6.0->Flask) (3.21.0)
# Collecting MarkupSafe>=2.0 (from Jinja2>=3.1.2->Flask)
#   Using cached MarkupSafe-2.1.5-cp38-cp38-win_amd64.whl.metadata (3.1 kB)
# Collecting pytz>=2020.1 (from pandas>=1.2->seaborn)
#   Downloading pytz-2026.1.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.1 (from pandas>=1.2->seaborn)
#   Using cached tzdata-2026.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: soupsieve>=1.6.1 in d:\anaconda\envs\kidney\lib\site-packages (from beautifulsoup4->gdown) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in d:\anaconda\envs\kidney\lib\site-packages (from beautifulsoup4->gdown) (4.12.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\anaconda\envs\kidney\lib\site-packages (from requests[socks]->gdown) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\envs\kidney\lib\site-packages (from requests[socks]->gdown) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\envs\kidney\lib\site-packages (from requests[socks]->gdown) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\envs\kidney\lib\site-packages (from requests[socks]->gdown) (2026.2.25)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in d:\anaconda\envs\kidney\lib\site-packages (from requests[socks]->gdown) (1.7.1)
# Downloading ensure-1.0.2-py2.py3-none-any.whl (15 kB)
# Downloading matplotlib-3.7.5-cp38-cp38-win_amd64.whl (7.5 MB)
#    ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.5 MB 1.3 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.0/7.5 MB 1.6 MB/s eta 0:00:04
#    -------- ------------------------------- 1.6/7.5 MB 1.9 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.1/7.5 MB 2.1 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.1/7.5 MB 2.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.5/7.5 MB 3.2 MB/s eta 0:00:01
#    --------------------------- ------------ 5.2/7.5 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.6/7.5 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 7.5/7.5 MB 3.8 MB/s eta 0:00:00
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading types_PyYAML-6.0.12.20241230-py3-none-any.whl (20 kB)
# Using cached scipy-1.10.1-cp38-cp38-win_amd64.whl (42.2 MB)
# Using cached flask-3.0.3-py3-none-any.whl (101 kB)
# Using cached Flask_Cors-5.0.0-py2.py3-none-any.whl (14 kB)
# Using cached blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Downloading contourpy-1.1.1-cp38-cp38-win_amd64.whl (477 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.57.0-cp38-cp38-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------- ----- 1.3/1.5 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 6.7 MB/s eta 0:00:00
# Using cached importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading kiwisolver-1.4.7-cp38-cp38-win_amd64.whl (55 kB)
# Downloading numpy-1.24.4-cp38-cp38-win_amd64.whl (14.9 MB)
#    ---------------------------------------- 0.0/14.9 MB ? eta -:--:--
#    --- ------------------------------------ 1.3/14.9 MB 7.4 MB/s eta 0:00:02
#    ------- -------------------------------- 2.6/14.9 MB 7.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.2/14.9 MB 7.0 MB/s eta 0:00:02
#    --------------- ------------------------ 5.8/14.9 MB 7.0 MB/s eta 0:00:02
#    ------------------- -------------------- 7.1/14.9 MB 7.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 8.4/14.9 MB 6.9 MB/s eta 0:00:01
#    -------------------------- ------------- 9.7/14.9 MB 6.9 MB/s eta 0:00:01
#    ------------------------------ --------- 11.3/14.9 MB 7.0 MB/s eta 0:00:01
#    --------------------------------- ------ 12.6/14.9 MB 6.9 MB/s eta 0:00:01
#    -------------------------------------- - 14.2/14.9 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------- 14.9/14.9 MB 6.8 MB/s eta 0:00:00
# Downloading pandas-2.0.3-cp38-cp38-win_amd64.whl (10.8 MB)
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/10.8 MB 7.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.9/10.8 MB 7.0 MB/s eta 0:00:02
#    --------------- ------------------------ 4.2/10.8 MB 7.2 MB/s eta 0:00:01
#    --------------------- ------------------ 5.8/10.8 MB 7.0 MB/s eta 0:00:01
#    -------------------------- ------------- 7.1/10.8 MB 7.0 MB/s eta 0:00:01
#    -------------------------------- ------- 8.7/10.8 MB 7.1 MB/s eta 0:00:01
#    ------------------------------------ --- 10.0/10.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------- 10.8/10.8 MB 6.9 MB/s eta 0:00:00
# Using cached pillow-10.4.0-cp38-cp38-win_amd64.whl (2.6 MB)
# Using cached pyparsing-3.1.4-py3-none-any.whl (104 kB)
# Using cached werkzeug-3.0.6-py3-none-any.whl (227 kB)
# Using cached MarkupSafe-2.1.5-cp38-cp38-win_amd64.whl (17 kB)
# Downloading pytz-2026.1.post1-py2.py3-none-any.whl (510 kB)
# Downloading tzdata-2026.1-py2.py3-none-any.whl (348 kB)
# Installing collected packages: pytz, tzdata, types-PyYAML, pyparsing, pillow, numpy, MarkupSafe, kiwisolver, joblib, itsdangerous, importlib-resources, fonttools, ensure, cycler, click, blinker, Werkzeug, scipy, pandas, Jinja2, contourpy, matplotlib, Flask, seaborn, Flask-Cors
# Successfully installed Flask-3.0.3 Flask-Cors-5.0.0 Jinja2-3.1.6 MarkupSafe-2.1.5 Werkzeug-3.0.6 blinker-1.8.2 click-8.1.8 contourpy-1.1.1 cycler-0.12.1 ensure-1.0.2 fonttools-4.57.0 importlib-resources-6.4.5 itsdangerous-2.2.0 joblib-1.4.2 kiwisolver-1.4.7 matplotlib-3.7.5 numpy-1.24.4 pandas-2.0.3 pillow-10.4.0 pyparsing-3.1.4 pytz-2026.1.post1 scipy-1.10.1 seaborn-0.13.2 types-PyYAML-6.0.12.20241230 tzdata-2026.1

# %%
# !pip install pyyaml
from cnnClassifier.constants import *
from cnnClassifier.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])


    
    def get_data_ingestion_config(self) -> DataIngestionConfig:
        config = self.config.data_ingestion

        create_directories([config.root_dir])

        data_ingestion_config = DataIngestionConfig(
            root_dir=config.root_dir,
            source_URL=config.source_URL,
            local_data_file=config.local_data_file,
            unzip_dir=config.unzip_dir 
        )

        return data_ingestion_config

# %%
import os
import zipfile
import gdown
from cnnClassifier import logger
from cnnClassifier.utils.common import get_size

# %%
class DataIngestion:
    def __init__(self, config: DataIngestionConfig):
        self.config = config

    
    def download_file(self)-> str:
        '''
        Fetch data from the url
        '''

        try: 
            dataset_url = self.config.source_URL
            zip_download_dir = self.config.local_data_file
            os.makedirs("artifacts/data_ingestion", exist_ok=True)
            logger.info(f"Downloading data from {dataset_url} into file {zip_download_dir}")

            file_id = dataset_url.split("/")[-2]
            prefix = 'https://drive.google.com/uc?/export=download&id='
            gdown.download(prefix+file_id,zip_download_dir)

            logger.info(f"Downloaded data from {dataset_url} into file {zip_download_dir}")

        except Exception as e:
            raise e
        
    

    def extract_zip_file(self):
        """
        zip_file_path: str
        Extracts the zip file into the data directory
        Function returns None
        """
        unzip_path = self.config.unzip_dir
        os.makedirs(unzip_path, exist_ok=True)
        with zipfile.ZipFile(self.config.local_data_file, 'r') as zip_ref:
            zip_ref.extractall(unzip_path)

# %%
try:
    config = ConfigurationManager()
    data_ingestion_config = config.get_data_ingestion_config()
    data_ingestion = DataIngestion(config=data_ingestion_config)
    data_ingestion.download_file()
    data_ingestion.extract_zip_file()
except Exception as e:
    raise e
# Out:
# [2026-04-13 14:56:45,196: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2026-04-13 14:56:45,197: INFO: common: yaml file: params.yaml loaded successfully]
# [2026-04-13 14:56:45,198: INFO: common: created directory at: artifacts]
# [2026-04-13 14:56:45,200: INFO: common: created directory at: artifacts/data_ingestion]
# [2026-04-13 14:56:45,201: INFO: 3172177572: Downloading data from https://drive.google.com/file/d/1h51UjW5f4nGoAlXuLBlj4Xa9RmQ0g3rt/view?usp=sharing into file artifacts/data_ingestion/data.zip]
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1h51UjW5f4nGoAlXuLBlj4Xa9RmQ0g3rt
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1h51UjW5f4nGoAlXuLBlj4Xa9RmQ0g3rt&confirm=t&uuid=378fdc6d-e064-4cfa-9564-fd47879b8d79
# To: d:\major(kidney)\Kidney-Disease-Classification-Deep-Learning-Project\artifacts\data_ingestion\data.zip
#   1%|          | 8.91M/941M [09:10<11:01:40, 23.5kB/s]
