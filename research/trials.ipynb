# %%
# config box
d = {"key":"val", "key1":"val1"}

# %%
d['key1']
# Out:
# 'val1'

# %%
# !pip install python-box==6.0.2
# Out:
# Collecting python-box==6.0.2
#   Using cached python_box-6.0.2-cp38-cp38-win_amd64.whl.metadata (7.7 kB)
# Downloading python_box-6.0.2-cp38-cp38-win_amd64.whl (944 kB)
#    ---------------------------------------- 0.0/944.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/944.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/944.1 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/944.1 kB ? eta -:--:--
#    ---------------------- ----------------- 524.3/944.1 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 944.1/944.1 kB 1.4 MB/s eta 0:00:00
# Installing collected packages: python-box
# Successfully installed python-box-6.0.2

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"key":"val", "key1":"val1"})

# %%
d2.key1
# Out:
# 'val1'

# %%
# ensure annotations 

def get_prodict(x:int, y:int) -> int:
    return x*y

# %%
get_prodict(x=2, y=3)
# Out:
# 6

# %%
# !pip install gdown
import gdown
# Out:
# Collecting gdown
#   Using cached gdown-5.2.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting beautifulsoup4 (from gdown)
#   Using cached beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting filelock (from gdown)
#   Using cached filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting requests[socks] (from gdown)
#   Using cached requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting tqdm (from gdown)
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4->gdown)
#   Downloading soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in d:\anaconda\envs\kidney\lib\site-packages (from beautifulsoup4->gdown) (4.12.2)
# Collecting charset_normalizer<4,>=2 (from requests[socks]->gdown)
#   Downloading charset_normalizer-3.4.7-cp38-cp38-win_amd64.whl.metadata (41 kB)
# Collecting idna<4,>=2.5 (from requests[socks]->gdown)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests[socks]->gdown)
#   Using cached urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests[socks]->gdown)
#   Downloading certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]->gdown)
#   Downloading PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: colorama in d:\anaconda\envs\kidney\lib\site-packages (from tqdm->gdown) (0.4.6)
# Downloading gdown-5.2.2-py3-none-any.whl (18 kB)
# Downloading beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Using cached filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Downloading certifi-2026.2.25-py3-none-any.whl (153 kB)
# Downloading charset_normalizer-3.4.7-cp38-cp38-win_amd64.whl (151 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Downloading soupsieve-2.7-py3-none-any.whl (36 kB)
# Using cached urllib3-2.2.3-py3-none-any.whl (126 kB)
# Using cached requests-2.32.4-py3-none-any.whl (64 kB)
# Installing collected packages: urllib3, tqdm, soupsieve, PySocks, idna, filelock, charset_normalizer, certifi, requests, beautifulsoup4, gdown
# Successfully installed PySocks-1.7.1 beautifulsoup4-4.14.3 certifi-2026.2.25 charset_normalizer-3.4.7 filelock-3.16.1 gdown-5.2.2 idna-3.11 requests-2.32.4 soupsieve-2.7 tqdm-4.67.3 urllib3-2.2.3

# %%
url="https://drive.google.com/file/d/1h51UjW5f4nGoAlXuLBlj4Xa9RmQ0g3rt/view?usp=sharing"

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1h51UjW5f4nGoAlXuLBlj4Xa9RmQ0g3rt'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "kidney-ct-scan-image.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1h51UjW5f4nGoAlXuLBlj4Xa9RmQ0g3rt
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1h51UjW5f4nGoAlXuLBlj4Xa9RmQ0g3rt&confirm=t&uuid=d6e1a734-e822-45eb-91e0-d829a184f364
# To: d:\major(kidney)\Kidney-Disease-Classification-Deep-Learning-Project\research\kidney-ct-scan-image.zip
# 100%|██████████| 941M/941M [06:09<00:00, 2.55MB/s]
# 'kidney-ct-scan-image.zip'
